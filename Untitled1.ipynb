# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilkundu601/python-twitter-data/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description: This is sentiment analysis program using python 
# !pip install tweepy

# %%
# Imoport the librarys

import tweepy as tw 
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
API_KEY="odYKclJIdXjqVD7IN0LX0UY9o"
API_KEY_SECRET="VU3IpdGwzyHQv5XTos0fkK2XHUHfhf4fqg3abB4hX2muoc4Ozu"
ACCESS_TOKEN="1505086706009387010-WVIs81ys2h55CHFWhdLXoLjBrCHjnZ"
ACCESS_TOKEN_SECRET="85bvYYneQykxPn40JwGYu1wH8JZjVoNNfLwdveKOw9JGJ"

# %%
auth= tw.OAuthHandler(API_KEY,API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN,ACCESS_TOKEN_SECRET)

# %%
api=tw.API(auth,wait_on_rate_limit=True)

# %%
#(hastag="#Ebike"


#query= tw.Cursor(api.search,
 #                  q=hashtag,
   #                since="2020-01-01",
    #               until="2022-01-01").items(20000)
#tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in query]
#print(tweets))                                      
hashtag = "#ebike"

#query=(tw.Cursor(api.search, q=hashtag).items(2000)
 
#tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in query]
#print(tweets)   


hashtag = "#ebike"
query = tw.Cursor(api.search, q=hashtag).items(1000)
tweets = [{'Tweet':tweet.text, 'Timestamp':tweet.created_at} for tweet in query]
print(tweets)
# Out:
# [{'Tweet': 'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…', 'Timestamp': datetime.datetime(2022, 3, 27, 12, 58, 35)}, {'Tweet': 'RT @maro17tweet: 締切り迫る！\nMARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n\n3/31 23:59まで\n\nMATE. BIKEの「MATE X」がMARO17別注で登場！\n\n応募方法↓\n①本アカウント（@maro17tweet）をフォロ…', 'Timestamp': datetime.datetime(2022, 3, 27, 12, 57, 1)}, {'Tweet': 'E-BIKE  wurde gerade veröffentlicht! https://t.co/fPh7uFXtv4 Vielen Dank an @CKemfert @DerGraslutscher @VQuaschning #fahrrad #ebike', 'Timestamp': datetime.datetime(2022, 3, 27, 12, 40, 30)}, {'Tweet': 'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…', 'Timestamp': datetime.datetime(2022, 3, 27, 12, 31, 50)}, {'Tweet': 'LUUP（ループ）のような電動アシスト自転車を購入したい方におすすめの6選\n\nhttps://t.co/nlcXv4E5UJ\n\n#アシスト自転車\u3000#電動自転車\u3000#電動アシスト自転車\u3000#Ebike', 'Timestamp'
# ...

# %%
df = pd.DataFrame.from_dict(tweets)

# %%
df.to_csv('ebike')

# %%
df = pd.read_csv('ebike')

print(df.to_string())

# %%
#data_list=[]
#for sent in df['Text']:
#    data_list.append(sent)
df = pd.read_csv('ebike', delimiter=',')

data_list = [list(row) for row in df.values]

print(data_list)
# Out:
# [[0, 'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…', '2022-03-27 12:58:35'], [1, 'RT @maro17tweet: 締切り迫る！\nMARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n\n3/31 23:59まで\n\nMATE. BIKEの「MATE X」がMARO17別注で登場！\n\n応募方法↓\n①本アカウント（@maro17tweet）をフォロ…', '2022-03-27 12:57:01'], [2, 'E-BIKE  wurde gerade veröffentlicht! https://t.co/fPh7uFXtv4 Vielen Dank an @CKemfert @DerGraslutscher @VQuaschning #fahrrad #ebike', '2022-03-27 12:40:30'], [3, 'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…', '2022-03-27 12:31:50'], [4, 'LUUP（ループ）のような電動アシスト自転車を購入したい方におすすめの6選\n\nhttps://t.co/nlcXv4E5UJ\n\n#アシスト自転車\u3000#電動自転車\u3000#電動アシスト自転車\u3000#Ebike', '2022-03-27 12:24:19'], [5, 'RT @maro17tweet: 締切り迫る！\nMARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n\n3/31 23:59まで\n\nMATE. BIKEの「MATE X」がMARO17別注で登場！\n\n応募方法↓\n①本アカウント（@maro17tweet）をフォロ
# ...

# %%
data_list
# Out:
# [[0,
#   'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…',
#   '2022-03-27 12:58:35'],
#  [1,
#   'RT @maro17tweet: 締切り迫る！\nMARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n\n3/31 23:59まで\n\nMATE. BIKEの「MATE X」がMARO17別注で登場！\n\n応募方法↓\n①本アカウント（@maro17tweet）をフォロ…',
#   '2022-03-27 12:57:01'],
#  [2,
#   'E-BIKE  wurde gerade veröffentlicht! https://t.co/fPh7uFXtv4 Vielen Dank an @CKemfert @DerGraslutscher @VQuaschning #fahrrad #ebike',
#   '2022-03-27 12:40:30'],
#  [3,
#   'RT @maro17tweet: MARO17別注のe-BIKEが当たる！Twitterキャンペーン！\n3/31 23:59まで。\n\n応募方法↓\n①本アカウント（@maro17_tweet）をフォロー\n②『#MARO17別注MATE』を付けて、ツイート\nのたったの2STEP。…',
#   '2022-03-27 12:31:50'],
#  [4,
#   'LUUP（ループ）のような電動アシスト自転車を購入したい方におすすめの6選\n\nhttps://t.co/nlcXv4E5UJ\n\n#アシスト自転車\u3000#電動自転車\u3000#電動アシスト自転車\u3000#Ebike',
#   '2022-03-27 12:24:19'],
#  [5,
# ...

# %%
import re 
#REMOVAL OF EMAILID
#data= re.compile("[0-9]{3,500}\.?[0-9]{0,500}?@")
data=[re.sub('\s*@\s*\s?','',sent) for sent in data_list]
# REMOVAL OF NELINE CHARACTER
data=[re.sub('\s+',' ',sent) for sent in data_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7896ee65219b> in <module>()
#       2 #REMOVAL OF EMAILID
#       3 #data= re.compile("[0-9]{3,500}\.?[0-9]{0,500}?@")
# ----> 4 data=[re.sub('\s*@\s*\s?','',sent) for sent in data_list]
#       5 # REMOVAL OF NELINE CHARACTER
#       6 data=[re.sub('\s+',' ',sent) for sent in data_list]
#
# NameError: name 'data_list' is not defined
